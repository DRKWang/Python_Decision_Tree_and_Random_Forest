# %%
# Importing necessary modules

import sklearn.datasets as datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn import tree
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %% [raw]
# eventtime.toString() +", " +
# eventtime.getTime() +", " +
# mapCoordinate.latitude_deg  + ", " +
# mapCoordinate.longitude_deg + ", " +
# intentModelData[ALTITUDE_FT] +", "+
# intentModelData[GROUNDTRACK_DEG] +", "+
# intentModelData[GROUNDSPEED_KTS] +", "+
# intentModelData[VERTICALSPEED_FT_PER_MIN] +", "+
# winningVerticalModel.getLabel() +", "+
# winningHorizontalModel.getLabel() +", "+
# winningSpeedModel.getLabel();

# %%
import pandas as pd 
# read text file into pandas DataFrame and 
# create header 
import os
Column_names = ["TIME_str", "TIME_sec", "latitude", "longitude", "ALTITUDE_FT", "GROUNDTRACK_DEG", \
            "GROUNDSPEED_KTS", "VERTICALSPEED_FT_PER_MIN", "Vertical_label",\
           "Horizontal_label", "Speed_label", "Turn_rate_deg_per_sec", "REL_HEADING", "DIST_TO_DEST", "MANEUVER_ID" ]
Selected_col_names = ["GROUNDSPEED_KTS", "REL_HEADING", "DIST_TO_DEST"]
Target_category_name = "Horizontal_label"
data_name = "HOLD_3"
cwd = os.getcwd()
mypath = cwd + f"/../data/{data_name}/"
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
count = 0

for file_name in onlyfiles:
    if "Traj" in file_name:
        if count == 0:
            file_path = mypath + file_name
            df = pd.read_csv(file_path, sep=",", header=None)
            df.columns = Column_names
            X_df = df[Selected_col_names]
            Y_target = df[Target_category_name]
        else:
            file_path = mypath + file_name
            df_temp = pd.read_csv(file_path, sep=",", header=None)
            df_temp.columns = Column_names
            
            X_df_temp = df_temp[Selected_col_names]
            Y_target_temp = df_temp[Target_category_name]
            X_df = pd.concat([X_df, X_df_temp])
            Y_target = pd.concat([Y_target, Y_target_temp])
        count +=1
        # if count >= 10:
        #     break

# %%
X_df["GROUNDSPEED_KTS"].max()
# Out:
# 547.0

# %%
X_df["GROUNDSPEED_KTS"].min()
# Out:
# 0.0

# %%
target_names =  list(set(list(Y_target)))
word_map_to_num = set(list(Y_target))
print("category:")
word_map_to_num
# Out:
# category:
# {' Fly Towards Destination',
#  ' Flying opposite established course',
#  ' Hold Left Turn -1.5DegPerSec',
#  ' Hold Left Turn -3.0DegPerSec',
#  ' Hold Right Turn 1.5DegPerSec',
#  ' Hold Right Turn 3.0DegPerSec',
#  ' Maintain Current Heading',
#  ' No Conclusion: Horizontal'}

# %%
n_sample = len(X_df)
print("number of points:", n_sample)
X_df = X_df.head(n_sample)
Y_target = Y_target.head(n_sample)
Y = []
for y in Y_target:
    for idx, s in enumerate(word_map_to_num):
        if s == y:
            Y.append(idx)
Y = np.array(Y)
# Out:
# number of points: 54570

# %%
import pandas as pd 
import dtreeviz
from sklearn.tree import export_text
# read text file into pandas DataFrame and 
# create header 
import os
cwd = os.getcwd()

# file_name_test = "Traj_AAL80-11121269.dat" # worst
file_name_test = "Traj_AAL245-11147798_L_HOLD.dat" # normal

file_path_test = mypath + file_name_test


# file_name_test = "Traj_AAL1252-11172342POS_HOLD.dat"

# file_path_test = cwd + "/../data/HOLD/" + file_name_test


df_test = pd.read_csv(file_path_test, sep=",", header=None)
df_test.columns = Column_names
X_df_test = df_test[Selected_col_names]

# %%
print("number of testing points:", len(X_df_test))
# Out:
# number of testing points: 3407

# %%
Z_target = df_test[Target_category_name]
n_sample = len(X_df_test)
X_df_test = X_df_test.head(n_sample)
Z_target = Z_target.head(n_sample)
Z = []
for z in Z_target:
    for idx, s in enumerate(word_map_to_num):
        if s == z:
            Z.append(idx)
Z = np.array(Z)
len(Z)
# Out:
# 3407

# %% [markdown]
# ## target 1: Horizontal_label

# %% [markdown]
# # Entropy

# %%
# Entropy, small tree with train data

criterion = "entropy"
max_depth = 6
dtree_small_entropy = DecisionTreeClassifier(criterion=criterion, max_depth=max_depth, min_samples_leaf=20)   # (random_state=1234)
model=dtree_small_entropy.fit(X_df,Y)
res = np.array(model.predict(X_df))
diff = res - Y
accuracy = 1/len(res) * sum([1 for x in diff if x == 0])
print(accuracy)
viz_model = dtreeviz.model(dtree_small_entropy, X_df, Y,
                target_name="target",
                feature_names=list(X_df.columns),
                class_names=target_names)

v = viz_model.view()     # render as SVG into internal object 
v                 # pop up window
v.save(f"{data_name}_all_{Target_category_name}_{criterion}_without_xy_" + f"max_depth:{max_depth}"  + ".svg")  # optionally save as svg
# Out:
# 0.7288986622686459
# /Users/binshuaiwang/PycharmProjects/XAI_project/venv/lib/python3.10/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names

# %%
# Entropy, small tree with train data
from sklearn.tree import export_text
from sklearn.tree import export_text_in_conditions

criterion = "entropy"
dtree_small_entropy = DecisionTreeClassifier(criterion=criterion, max_depth=max_depth, min_samples_leaf=20)   # (random_state=1234)
model=dtree_small_entropy.fit(X_df,Y)
res = np.array(model.predict(X_df))
diff = res - Y
accuracy = 1/len(res) * sum([1 for x in diff if x == 0])
print(accuracy)
viz_model = dtreeviz.model(dtree_small_entropy, X_df, Y,
                target_name="target",
                feature_names=list(X_df.columns),
                class_names=target_names)

v = viz_model.view()     # render as SVG into internal object 
v                 # pop up window
v.save(f"{data_name}_all_{Target_category_name}_{criterion}_without_xy_" + f"max_depth:{max_depth}"  + ".svg")  # optionally save as svg
r = export_text_in_conditions(dtree_small_entropy, feature_names=list(X_df.columns), class_names=target_names, show_weights=False)
# Out:
# 0.7288986622686459
# /Users/binshuaiwang/PycharmProjects/XAI_project/venv/lib/python3.10/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING <= -120.14 && REL_HEADING <= -142.00 && DIST_TO_DEST <= 70.47 && DIST_TO_DEST <= 32.28 && GROUNDSPEED_KTS <= 199.50, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING <= -120.14 && REL_HEADING <= -142.00 && DIST_TO_DEST <= 70.47 && DIST_TO_DEST <= 32.28 && GROUNDSPEED_KTS > 199.50, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING <= -120.14 && REL_HEADING <= -142.00 && DIST_TO_DEST <= 70.47 && DIST_TO_DEST > 32.28 && DIST_TO_DEST <= 34.00, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING <= -120.14 && REL_HEADING <= -142.00 && DIST_TO_DEST <= 70.47 && DIST_TO_DEST > 32.28 && DIST_TO_DEST > 34.00, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING <= -120.14 && REL_HEADING <= -142.00 && DIST_TO_DEST > 70.47 && DIST_TO_DEST <= 243.94 && REL_HEADING <= -151.86, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING <= -120.14 && REL_HEADING <= -142.00 && DIST_TO_DEST > 70.47 && DIST_TO_DEST <= 243.94 && REL_HEADING > -151.86, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING <= -120.14 && REL_HEADING <= -142.00 && DIST_TO_DEST > 70.47 && DIST_TO_DEST > 243.94, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING <= -120.14 && REL_HEADING > -142.00 && GROUNDSPEED_KTS <= 264.50 && REL_HEADING <= -126.08 && GROUNDSPEED_KTS <= 246.50, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING <= -120.14 && REL_HEADING > -142.00 && GROUNDSPEED_KTS <= 264.50 && REL_HEADING <= -126.08 && GROUNDSPEED_KTS > 246.50, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING <= -120.14 && REL_HEADING > -142.00 && GROUNDSPEED_KTS <= 264.50 && REL_HEADING > -126.08 && DIST_TO_DEST <= 32.04, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING <= -120.14 && REL_HEADING > -142.00 && GROUNDSPEED_KTS <= 264.50 && REL_HEADING > -126.08 && DIST_TO_DEST > 32.04, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING <= -120.14 && REL_HEADING > -142.00 && GROUNDSPEED_KTS > 264.50 && GROUNDSPEED_KTS <= 277.50 && DIST_TO_DEST <= 51.63, then  class:  Fly Towards Destination
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING <= -120.14 && REL_HEADING > -142.00 && GROUNDSPEED_KTS > 264.50 && GROUNDSPEED_KTS <= 277.50 && DIST_TO_DEST > 51.63, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING <= -120.14 && REL_HEADING > -142.00 && GROUNDSPEED_KTS > 264.50 && GROUNDSPEED_KTS > 277.50 && DIST_TO_DEST <= 66.47, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING <= -120.14 && REL_HEADING > -142.00 && GROUNDSPEED_KTS > 264.50 && GROUNDSPEED_KTS > 277.50 && DIST_TO_DEST > 66.47, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING > -120.14 && REL_HEADING <= 120.50 && GROUNDSPEED_KTS <= 180.50 && DIST_TO_DEST <= 19.94 && GROUNDSPEED_KTS <= 1.50, then  class:  No Conclusion: Horizontal
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING > -120.14 && REL_HEADING <= 120.50 && GROUNDSPEED_KTS <= 180.50 && DIST_TO_DEST <= 19.94 && GROUNDSPEED_KTS > 1.50, then  class:  No Conclusion: Horizontal
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING > -120.14 && REL_HEADING <= 120.50 && GROUNDSPEED_KTS <= 180.50 && DIST_TO_DEST > 19.94 && GROUNDSPEED_KTS <= 177.50, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING > -120.14 && REL_HEADING <= 120.50 && GROUNDSPEED_KTS <= 180.50 && DIST_TO_DEST > 19.94 && GROUNDSPEED_KTS > 177.50, then  class:  No Conclusion: Horizontal
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING > -120.14 && REL_HEADING <= 120.50 && GROUNDSPEED_KTS > 180.50 && REL_HEADING <= -61.49 && DIST_TO_DEST <= 59.61, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING > -120.14 && REL_HEADING <= 120.50 && GROUNDSPEED_KTS > 180.50 && REL_HEADING <= -61.49 && DIST_TO_DEST > 59.61, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING > -120.14 && REL_HEADING <= 120.50 && GROUNDSPEED_KTS > 180.50 && REL_HEADING > -61.49 && REL_HEADING <= 60.94, then  class:  No Conclusion: Horizontal
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING > -120.14 && REL_HEADING <= 120.50 && GROUNDSPEED_KTS > 180.50 && REL_HEADING > -61.49 && REL_HEADING > 60.94, then  class:  No Conclusion: Horizontal
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING > -120.14 && REL_HEADING > 120.50 && GROUNDSPEED_KTS <= 257.50 && REL_HEADING <= 148.09 && DIST_TO_DEST <= 44.21, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING > -120.14 && REL_HEADING > 120.50 && GROUNDSPEED_KTS <= 257.50 && REL_HEADING <= 148.09 && DIST_TO_DEST > 44.21, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING > -120.14 && REL_HEADING > 120.50 && GROUNDSPEED_KTS <= 257.50 && REL_HEADING > 148.09, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING > -120.14 && REL_HEADING > 120.50 && GROUNDSPEED_KTS > 257.50 && REL_HEADING <= 162.84 && GROUNDSPEED_KTS <= 311.50, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING > -120.14 && REL_HEADING > 120.50 && GROUNDSPEED_KTS > 257.50 && REL_HEADING <= 162.84 && GROUNDSPEED_KTS > 311.50, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING > -120.14 && REL_HEADING > 120.50 && GROUNDSPEED_KTS > 257.50 && REL_HEADING > 162.84 && GROUNDSPEED_KTS <= 308.50, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS <= 320.50 && REL_HEADING > -120.14 && REL_HEADING > 120.50 && GROUNDSPEED_KTS > 257.50 && REL_HEADING > 162.84 && GROUNDSPEED_KTS > 308.50, then  class:  Hold Right Turn 1.5DegPerSec
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING <= 67.75 && REL_HEADING <= -27.08 && GROUNDSPEED_KTS <= 415.50 && REL_HEADING <= -143.93 && GROUNDSPEED_KTS <= 411.50, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING <= 67.75 && REL_HEADING <= -27.08 && GROUNDSPEED_KTS <= 415.50 && REL_HEADING <= -143.93 && GROUNDSPEED_KTS > 411.50, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING <= 67.75 && REL_HEADING <= -27.08 && GROUNDSPEED_KTS <= 415.50 && REL_HEADING > -143.93 && DIST_TO_DEST <= 312.62, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING <= 67.75 && REL_HEADING <= -27.08 && GROUNDSPEED_KTS <= 415.50 && REL_HEADING > -143.93 && DIST_TO_DEST > 312.62, then  class:  Hold Right Turn 1.5DegPerSec
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING <= 67.75 && REL_HEADING <= -27.08 && GROUNDSPEED_KTS > 415.50 && DIST_TO_DEST <= 320.43 && REL_HEADING <= -58.82, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING <= 67.75 && REL_HEADING <= -27.08 && GROUNDSPEED_KTS > 415.50 && DIST_TO_DEST <= 320.43 && REL_HEADING > -58.82, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING <= 67.75 && REL_HEADING <= -27.08 && GROUNDSPEED_KTS > 415.50 && DIST_TO_DEST > 320.43 && REL_HEADING <= -62.82, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING <= 67.75 && REL_HEADING <= -27.08 && GROUNDSPEED_KTS > 415.50 && DIST_TO_DEST > 320.43 && REL_HEADING > -62.82, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING <= 67.75 && REL_HEADING > -27.08 && GROUNDSPEED_KTS <= 410.50 && REL_HEADING <= 8.01 && DIST_TO_DEST <= 163.13, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING <= 67.75 && REL_HEADING > -27.08 && GROUNDSPEED_KTS <= 410.50 && REL_HEADING <= 8.01 && DIST_TO_DEST > 163.13, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING <= 67.75 && REL_HEADING > -27.08 && GROUNDSPEED_KTS <= 410.50 && REL_HEADING > 8.01 && DIST_TO_DEST <= 118.37, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING <= 67.75 && REL_HEADING > -27.08 && GROUNDSPEED_KTS <= 410.50 && REL_HEADING > 8.01 && DIST_TO_DEST > 118.37, then  class:  Fly Towards Destination
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING <= 67.75 && REL_HEADING > -27.08 && GROUNDSPEED_KTS > 410.50 && REL_HEADING <= -19.71 && DIST_TO_DEST <= 232.10, then  class:  Fly Towards Destination
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING <= 67.75 && REL_HEADING > -27.08 && GROUNDSPEED_KTS > 410.50 && REL_HEADING <= -19.71 && DIST_TO_DEST > 232.10, then  class:  No Conclusion: Horizontal
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING <= 67.75 && REL_HEADING > -27.08 && GROUNDSPEED_KTS > 410.50 && REL_HEADING > -19.71 && GROUNDSPEED_KTS <= 484.50, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING <= 67.75 && REL_HEADING > -27.08 && GROUNDSPEED_KTS > 410.50 && REL_HEADING > -19.71 && GROUNDSPEED_KTS > 484.50, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING > 67.75 && REL_HEADING <= 141.62 && DIST_TO_DEST <= 140.87 && DIST_TO_DEST <= 62.77 && REL_HEADING <= 79.64, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING > 67.75 && REL_HEADING <= 141.62 && DIST_TO_DEST <= 140.87 && DIST_TO_DEST <= 62.77 && REL_HEADING > 79.64, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING > 67.75 && REL_HEADING <= 141.62 && DIST_TO_DEST <= 140.87 && DIST_TO_DEST > 62.77 && DIST_TO_DEST <= 89.41, then  class:  Hold Right Turn 1.5DegPerSec
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING > 67.75 && REL_HEADING <= 141.62 && DIST_TO_DEST <= 140.87 && DIST_TO_DEST > 62.77 && DIST_TO_DEST > 89.41, then  class:  Hold Right Turn 1.5DegPerSec
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING > 67.75 && REL_HEADING <= 141.62 && DIST_TO_DEST > 140.87 && DIST_TO_DEST <= 309.77 && REL_HEADING <= 137.77, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING > 67.75 && REL_HEADING <= 141.62 && DIST_TO_DEST > 140.87 && DIST_TO_DEST <= 309.77 && REL_HEADING > 137.77, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING > 67.75 && REL_HEADING <= 141.62 && DIST_TO_DEST > 140.87 && DIST_TO_DEST > 309.77, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING > 67.75 && REL_HEADING > 141.62 && DIST_TO_DEST <= 42.37 && DIST_TO_DEST <= 37.34, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING > 67.75 && REL_HEADING > 141.62 && DIST_TO_DEST <= 42.37 && DIST_TO_DEST > 37.34, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING > 67.75 && REL_HEADING > 141.62 && DIST_TO_DEST > 42.37 && DIST_TO_DEST <= 306.30 && DIST_TO_DEST <= 115.28, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING > 67.75 && REL_HEADING > 141.62 && DIST_TO_DEST > 42.37 && DIST_TO_DEST <= 306.30 && DIST_TO_DEST > 115.28, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING > 67.75 && REL_HEADING > 141.62 && DIST_TO_DEST > 42.37 && DIST_TO_DEST > 306.30 && DIST_TO_DEST <= 311.67, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS > 320.50 && REL_HEADING > 67.75 && REL_HEADING > 141.62 && DIST_TO_DEST > 42.37 && DIST_TO_DEST > 306.30 && DIST_TO_DEST > 311.67, then  class:  Hold Right Turn 1.5DegPerSec

# %%
from sklearn.tree import export_text_in_words

r = export_text_in_words(X_df, dtree_small_entropy, feature_names=list(X_df.columns), class_names=target_names, show_weights=False)
# Out:
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely left, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is extremely close, and GROUNDSPEED_KTS is low, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely left, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is extremely close, and GROUNDSPEED_KTS is low, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely left, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is extremely close, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely left, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is extremely close, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely left, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is far, and REL_HEADING is extremely left, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely left, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is far, and REL_HEADING is extremely left, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely left, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is far, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely left, and GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and GROUNDSPEED_KTS is normal, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely left, and GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and GROUNDSPEED_KTS is normal, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely left, and GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and DIST_TO_DEST is extremely close, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely left, and GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and DIST_TO_DEST is extremely close, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely left, and GROUNDSPEED_KTS is normal, and GROUNDSPEED_KTS is normal, and DIST_TO_DEST is extremely close, then  class:  Fly Towards Destination
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely left, and GROUNDSPEED_KTS is normal, and GROUNDSPEED_KTS is normal, and DIST_TO_DEST is extremely close, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely left, and GROUNDSPEED_KTS is normal, and GROUNDSPEED_KTS is normal, and DIST_TO_DEST is extremely close, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely left, and GROUNDSPEED_KTS is normal, and GROUNDSPEED_KTS is normal, and DIST_TO_DEST is extremely close, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is low, and DIST_TO_DEST is extremely close, and GROUNDSPEED_KTS is very low, then  class:  No Conclusion: Horizontal
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is low, and DIST_TO_DEST is extremely close, and GROUNDSPEED_KTS is very low, then  class:  No Conclusion: Horizontal
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is low, and DIST_TO_DEST is extremely close, and GROUNDSPEED_KTS is low, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is low, and DIST_TO_DEST is extremely close, and GROUNDSPEED_KTS is low, then  class:  No Conclusion: Horizontal
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is low, and REL_HEADING is left, and DIST_TO_DEST is extremely close, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is low, and REL_HEADING is left, and DIST_TO_DEST is extremely close, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is low, and REL_HEADING is left, and REL_HEADING is right, then  class:  No Conclusion: Horizontal
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is low, and REL_HEADING is left, and REL_HEADING is right, then  class:  No Conclusion: Horizontal
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is normal, and REL_HEADING is extremely right, and DIST_TO_DEST is extremely close, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is normal, and REL_HEADING is extremely right, and DIST_TO_DEST is extremely close, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is normal, and REL_HEADING is extremely right, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is normal, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is normal, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is normal, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is normal, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is normal, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is normal, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is extremely left, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is normal, and REL_HEADING is extremely right, and GROUNDSPEED_KTS is normal, then  class:  Hold Right Turn 1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is straight, and GROUNDSPEED_KTS is high, and REL_HEADING is extremely left, and GROUNDSPEED_KTS is high, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is straight, and GROUNDSPEED_KTS is high, and REL_HEADING is extremely left, and GROUNDSPEED_KTS is high, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is straight, and GROUNDSPEED_KTS is high, and REL_HEADING is extremely left, and DIST_TO_DEST is far, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is straight, and GROUNDSPEED_KTS is high, and REL_HEADING is extremely left, and DIST_TO_DEST is far, then  class:  Hold Right Turn 1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is straight, and GROUNDSPEED_KTS is high, and DIST_TO_DEST is far, and REL_HEADING is left, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is straight, and GROUNDSPEED_KTS is high, and DIST_TO_DEST is far, and REL_HEADING is left, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is straight, and GROUNDSPEED_KTS is high, and DIST_TO_DEST is far, and REL_HEADING is left, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is straight, and GROUNDSPEED_KTS is high, and DIST_TO_DEST is far, and REL_HEADING is left, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is straight, and GROUNDSPEED_KTS is high, and REL_HEADING is straight, and DIST_TO_DEST is close, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is straight, and GROUNDSPEED_KTS is high, and REL_HEADING is straight, and DIST_TO_DEST is close, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is straight, and GROUNDSPEED_KTS is high, and REL_HEADING is straight, and DIST_TO_DEST is close, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is straight, and GROUNDSPEED_KTS is high, and REL_HEADING is straight, and DIST_TO_DEST is close, then  class:  Fly Towards Destination
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is straight, and GROUNDSPEED_KTS is high, and REL_HEADING is straight, and DIST_TO_DEST is close, then  class:  Fly Towards Destination
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is straight, and GROUNDSPEED_KTS is high, and REL_HEADING is straight, and DIST_TO_DEST is close, then  class:  No Conclusion: Horizontal
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is straight, and GROUNDSPEED_KTS is high, and REL_HEADING is straight, and GROUNDSPEED_KTS is very high, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is straight, and GROUNDSPEED_KTS is high, and REL_HEADING is straight, and GROUNDSPEED_KTS is very high, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is extremely right, and DIST_TO_DEST is close, and DIST_TO_DEST is extremely close, and REL_HEADING is right, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is extremely right, and DIST_TO_DEST is close, and DIST_TO_DEST is extremely close, and REL_HEADING is right, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is extremely right, and DIST_TO_DEST is close, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is extremely close, then  class:  Hold Right Turn 1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is extremely right, and DIST_TO_DEST is close, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is extremely close, then  class:  Hold Right Turn 1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is extremely right, and DIST_TO_DEST is close, and DIST_TO_DEST is far, and REL_HEADING is extremely right, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is extremely right, and DIST_TO_DEST is close, and DIST_TO_DEST is far, and REL_HEADING is extremely right, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is extremely right, and DIST_TO_DEST is close, and DIST_TO_DEST is far, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is extremely right, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is extremely close, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is extremely right, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is extremely close, then  class:  Maintain Current Heading
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is extremely right, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is far, and DIST_TO_DEST is extremely close, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is extremely right, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is far, and DIST_TO_DEST is extremely close, then  class:  Flying opposite established course
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is extremely right, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is far, and DIST_TO_DEST is far, then  class:  Hold Left Turn -1.5DegPerSec
#
# If GROUNDSPEED_KTS is normal, and REL_HEADING is right, and REL_HEADING is extremely right, and DIST_TO_DEST is extremely close, and DIST_TO_DEST is far, and DIST_TO_DEST is far, then  class:  Hold Right Turn 1.5DegPerSec

# %%
import graphviz
from sklearn.tree import export_graphviz
dot_data = export_graphviz(dtree_small_entropy,
                           feature_names=X_df.columns,  
                           class_names = target_names,

                           filled=True,  
                           rounded = True,
                            precision = 2,
                           proportion=True)
graph = graphviz.Source(dot_data)
graph.format = "png"
graph.render(f"{data_name}__all_{Target_category_name}_{criterion}" + "importances")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 import graphviz
#       2 from sklearn.tree import export_graphviz
# ----> 3 dot_data = export_graphviz(dtree_small_entropy,
#       4                            feature_names=X_df.columns,
#       5                            class_names = target_names,
#       6
#       7                            filled=True,
#       8                            rounded = True,
#       9                             precision = 2,
#      10                            proportion=True)
#      11 graph = graphviz.Source(dot_data)
#      12 graph.format = "png"
#
# File ~/PycharmProjects/XAI_project/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:192, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
# --> 192 params = func_sig.bind(*args, **kwargs)
#     193 params.apply_defaults()
#     195 # ignore self/cls and positional/keyword markers
#
# File /opt/local/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/inspect.py:3179, in Signature.bind(self, *args, **kwargs)
#    3174 def bind(self, /, *args, **kwargs):
#    3175     """Get a BoundArguments object, that maps the passed `args`
#    3176     and `kwargs` to the function's signature.  Raises `TypeError`
#    3177     if the passed arguments can not be bound.
#    3178     """
# -> 3179     return self._bind(args, kwargs)
#
# File /opt/local/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/inspect.py:3094, in Signature._bind(self, args, kwargs, partial)
#    3092                 msg = 'missing a required argument: {arg!r}'
#    3093                 msg = msg.format(arg=param.name)
# -> 3094                 raise TypeError(msg) from None
#    3095 else:
#    3096     # We have a positional argument to process
#    3097     try:
#
# TypeError: missing a required argument: 'decision_tree'

# %%
r = export_text(dtree_small_entropy, feature_names=list(X_df.columns), class_names=target_names, show_weights=False)

# %%
print(r)
# Out:
# |--- GROUNDSPEED_KTS <= 320.50
# |   |--- REL_HEADING <= -120.14
# |   |   |--- REL_HEADING <= -142.00
# |   |   |   |--- DIST_TO_DEST <= 70.47
# |   |   |   |   |--- DIST_TO_DEST <= 32.28
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 199.50
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  199.50
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- DIST_TO_DEST >  32.28
# |   |   |   |   |   |--- DIST_TO_DEST <= 34.00
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  34.00
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |--- DIST_TO_DEST >  70.47
# |   |   |   |   |--- DIST_TO_DEST <= 243.94
# |   |   |   |   |   |--- REL_HEADING <= -151.86
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- REL_HEADING >  -151.86
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  243.94
# |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |--- REL_HEADING >  -142.00
# |   |   |   |--- GROUNDSPEED_KTS <= 264.50
# |   |   |   |   |--- REL_HEADING <= -126.08
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 246.50
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  246.50
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  -126.08
# |   |   |   |   |   |--- DIST_TO_DEST <= 32.04
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- DIST_TO_DEST >  32.04
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |--- GROUNDSPEED_KTS >  264.50
# |   |   |   |   |--- GROUNDSPEED_KTS <= 277.50
# |   |   |   |   |   |--- DIST_TO_DEST <= 51.63
# |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |--- DIST_TO_DEST >  51.63
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- GROUNDSPEED_KTS >  277.50
# |   |   |   |   |   |--- DIST_TO_DEST <= 66.47
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  66.47
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |--- REL_HEADING >  -120.14
# |   |   |--- REL_HEADING <= 120.50
# |   |   |   |--- GROUNDSPEED_KTS <= 180.50
# |   |   |   |   |--- DIST_TO_DEST <= 19.94
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 1.50
# |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  1.50
# |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |--- DIST_TO_DEST >  19.94
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 177.50
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  177.50
# |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |--- GROUNDSPEED_KTS >  180.50
# |   |   |   |   |--- REL_HEADING <= -61.49
# |   |   |   |   |   |--- DIST_TO_DEST <= 59.61
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  59.61
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  -61.49
# |   |   |   |   |   |--- REL_HEADING <= 60.94
# |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |--- REL_HEADING >  60.94
# |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |--- REL_HEADING >  120.50
# |   |   |   |--- GROUNDSPEED_KTS <= 257.50
# |   |   |   |   |--- REL_HEADING <= 148.09
# |   |   |   |   |   |--- DIST_TO_DEST <= 44.21
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- DIST_TO_DEST >  44.21
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- REL_HEADING >  148.09
# |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |--- GROUNDSPEED_KTS >  257.50
# |   |   |   |   |--- REL_HEADING <= 162.84
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 311.50
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  311.50
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  162.84
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 308.50
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  308.50
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |--- GROUNDSPEED_KTS >  320.50
# |   |--- REL_HEADING <= 67.75
# |   |   |--- REL_HEADING <= -27.08
# |   |   |   |--- GROUNDSPEED_KTS <= 415.50
# |   |   |   |   |--- REL_HEADING <= -143.93
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 411.50
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  411.50
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  -143.93
# |   |   |   |   |   |--- DIST_TO_DEST <= 312.62
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  312.62
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |--- GROUNDSPEED_KTS >  415.50
# |   |   |   |   |--- DIST_TO_DEST <= 320.43
# |   |   |   |   |   |--- REL_HEADING <= -58.82
# |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |--- REL_HEADING >  -58.82
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  320.43
# |   |   |   |   |   |--- REL_HEADING <= -62.82
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- REL_HEADING >  -62.82
# |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |--- REL_HEADING >  -27.08
# |   |   |   |--- GROUNDSPEED_KTS <= 410.50
# |   |   |   |   |--- REL_HEADING <= 8.01
# |   |   |   |   |   |--- DIST_TO_DEST <= 163.13
# |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |--- DIST_TO_DEST >  163.13
# |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |--- REL_HEADING >  8.01
# |   |   |   |   |   |--- DIST_TO_DEST <= 118.37
# |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |--- DIST_TO_DEST >  118.37
# |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |--- GROUNDSPEED_KTS >  410.50
# |   |   |   |   |--- REL_HEADING <= -19.71
# |   |   |   |   |   |--- DIST_TO_DEST <= 232.10
# |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |--- DIST_TO_DEST >  232.10
# |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |--- REL_HEADING >  -19.71
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 484.50
# |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  484.50
# |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |--- REL_HEADING >  67.75
# |   |   |--- REL_HEADING <= 141.62
# |   |   |   |--- DIST_TO_DEST <= 140.87
# |   |   |   |   |--- DIST_TO_DEST <= 62.77
# |   |   |   |   |   |--- REL_HEADING <= 79.64
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- REL_HEADING >  79.64
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  62.77
# |   |   |   |   |   |--- DIST_TO_DEST <= 89.41
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  89.41
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |--- DIST_TO_DEST >  140.87
# |   |   |   |   |--- DIST_TO_DEST <= 309.77
# |   |   |   |   |   |--- REL_HEADING <= 137.77
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- REL_HEADING >  137.77
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  309.77
# |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |--- REL_HEADING >  141.62
# |   |   |   |--- DIST_TO_DEST <= 42.37
# |   |   |   |   |--- DIST_TO_DEST <= 37.34
# |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |--- DIST_TO_DEST >  37.34
# |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |--- DIST_TO_DEST >  42.37
# |   |   |   |   |--- DIST_TO_DEST <= 306.30
# |   |   |   |   |   |--- DIST_TO_DEST <= 115.28
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- DIST_TO_DEST >  115.28
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- DIST_TO_DEST >  306.30
# |   |   |   |   |   |--- DIST_TO_DEST <= 311.67
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  311.67
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec

# %%
tree = model.tree_

# %%
criterion = "entropy"
dtree_small_entropy = DecisionTreeClassifier(criterion=criterion, max_depth=10, min_samples_leaf=20)   # (random_state=1234)
model=dtree_small_entropy.fit(X_df,Y)
res = np.array(model.predict(X_df))
diff = res - Y
accuracy = 1/len(res) * sum([1 for x in diff if x == 0])
print(accuracy)
r = export_text(dtree_small_entropy, feature_names=list(X_df.columns), class_names=target_names, show_weights=False)
print(r)
# Out:
# 0.8327652556349643
# |--- GROUNDSPEED_KTS <= 320.50
# |   |--- REL_HEADING <= -120.14
# |   |   |--- REL_HEADING <= -142.00
# |   |   |   |--- DIST_TO_DEST <= 70.47
# |   |   |   |   |--- DIST_TO_DEST <= 32.28
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 199.50
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 187.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= -144.70
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- REL_HEADING >  -144.70
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  187.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= -154.30
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 4.04
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  4.04
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- REL_HEADING >  -154.30
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  199.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 30.79
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- DIST_TO_DEST >  30.79
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 31.53
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  31.53
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- DIST_TO_DEST >  32.28
# |   |   |   |   |   |--- DIST_TO_DEST <= 34.00
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 257.00
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  257.00
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 267.00
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  267.00
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 33.09
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  33.09
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  34.00
# |   |   |   |   |   |   |--- REL_HEADING <= -171.16
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 308.50
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  308.50
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  -171.16
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 61.76
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 43.25
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 40.26
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  40.26
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  43.25
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 59.59
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  59.59
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  61.76
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |--- DIST_TO_DEST >  70.47
# |   |   |   |   |--- DIST_TO_DEST <= 243.94
# |   |   |   |   |   |--- REL_HEADING <= -151.86
# |   |   |   |   |   |   |--- REL_HEADING <= -154.75
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -154.75
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- REL_HEADING >  -151.86
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  243.94
# |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |--- REL_HEADING >  -142.00
# |   |   |   |--- GROUNDSPEED_KTS <= 264.50
# |   |   |   |   |--- REL_HEADING <= -126.08
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 246.50
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  246.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 33.42
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 31.96
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  31.96
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  33.42
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- REL_HEADING >  -126.08
# |   |   |   |   |   |--- DIST_TO_DEST <= 32.04
# |   |   |   |   |   |   |--- REL_HEADING <= -120.17
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 24.85
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  24.85
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -120.17
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- DIST_TO_DEST >  32.04
# |   |   |   |   |   |   |--- REL_HEADING <= -125.60
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 52.42
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  52.42
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  -125.60
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |--- GROUNDSPEED_KTS >  264.50
# |   |   |   |   |--- GROUNDSPEED_KTS <= 277.50
# |   |   |   |   |   |--- DIST_TO_DEST <= 51.63
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 39.09
# |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |--- DIST_TO_DEST >  39.09
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 50.93
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 269.50
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  269.50
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  50.93
# |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |--- DIST_TO_DEST >  51.63
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- GROUNDSPEED_KTS >  277.50
# |   |   |   |   |   |--- DIST_TO_DEST <= 66.47
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 58.57
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  58.57
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  66.47
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |--- REL_HEADING >  -120.14
# |   |   |--- REL_HEADING <= 120.50
# |   |   |   |--- GROUNDSPEED_KTS <= 180.50
# |   |   |   |   |--- DIST_TO_DEST <= 19.94
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 1.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.04
# |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- DIST_TO_DEST >  0.04
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.04
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.04
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -4.88
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.13
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.13
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -4.88
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  1.50
# |   |   |   |   |   |   |--- REL_HEADING <= 5.83
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 22.50
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.00
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.20
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.20
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  22.50
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 13.13
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  13.13
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -14.87
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -14.87
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- REL_HEADING >  5.83
# |   |   |   |   |   |   |   |--- REL_HEADING <= 88.33
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.18
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.08
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.08
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.18
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.20
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.20
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- REL_HEADING >  88.33
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 103.20
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.37
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.37
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  103.20
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.17
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -3.0DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.17
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |--- DIST_TO_DEST >  19.94
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 177.50
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 174.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 20.81
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  20.81
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  174.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 35.54
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 35.39
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  35.39
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  35.54
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  177.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 35.56
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 21.57
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  21.57
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- DIST_TO_DEST >  35.56
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 38.08
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 36.40
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  36.40
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 37.27
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  37.27
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  38.08
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |--- GROUNDSPEED_KTS >  180.50
# |   |   |   |   |--- REL_HEADING <= -61.49
# |   |   |   |   |   |--- DIST_TO_DEST <= 59.61
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 225.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 10.88
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  10.88
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 3.0DegPerSec
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  225.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= -67.97
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- REL_HEADING >  -67.97
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 31.25
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  31.25
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 37.09
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  37.09
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  59.61
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 291.50
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  291.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 95.19
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  95.19
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  -61.49
# |   |   |   |   |   |--- REL_HEADING <= 60.94
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 288.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 14.88
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 214.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 11.90
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  11.90
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  214.50
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 20.52
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  20.52
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  14.88
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -30.16
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 49.12
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  49.12
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -30.16
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 279.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  279.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  288.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= 13.35
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 312.50
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 3.11
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  3.11
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  312.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 43.91
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  43.91
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- REL_HEADING >  13.35
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 39.38
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 37.46
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  37.46
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  39.38
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 310.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  310.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- REL_HEADING >  60.94
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 252.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 21.99
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 238.50
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 237.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  237.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  238.50
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 70.44
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  70.44
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  21.99
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 223.50
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  223.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 45.80
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  45.80
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  252.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 45.78
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 307.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 42.86
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  42.86
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  307.50
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  45.78
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 78.00
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 77.92
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  77.92
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  78.00
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |--- REL_HEADING >  120.50
# |   |   |   |--- GROUNDSPEED_KTS <= 257.50
# |   |   |   |   |--- REL_HEADING <= 148.09
# |   |   |   |   |   |--- DIST_TO_DEST <= 44.21
# |   |   |   |   |   |   |--- REL_HEADING <= 134.29
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  134.29
# |   |   |   |   |   |   |   |--- REL_HEADING <= 142.42
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- REL_HEADING >  142.42
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- DIST_TO_DEST >  44.21
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- REL_HEADING >  148.09
# |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |--- GROUNDSPEED_KTS >  257.50
# |   |   |   |   |--- REL_HEADING <= 162.84
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 311.50
# |   |   |   |   |   |   |--- REL_HEADING <= 149.73
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 262.50
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  262.50
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  149.73
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 300.50
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 160.23
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 51.80
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  51.80
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  160.23
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  300.50
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  311.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 53.10
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  53.10
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  162.84
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 308.50
# |   |   |   |   |   |   |--- REL_HEADING <= 166.33
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  166.33
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  308.50
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |--- GROUNDSPEED_KTS >  320.50
# |   |--- REL_HEADING <= 67.75
# |   |   |--- REL_HEADING <= -27.08
# |   |   |   |--- GROUNDSPEED_KTS <= 415.50
# |   |   |   |   |--- REL_HEADING <= -143.93
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 411.50
# |   |   |   |   |   |   |--- REL_HEADING <= -172.36
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  -172.36
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 136.06
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  136.06
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 238.42
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  238.42
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 317.45
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  317.45
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  411.50
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  -143.93
# |   |   |   |   |   |--- DIST_TO_DEST <= 312.62
# |   |   |   |   |   |   |--- REL_HEADING <= -44.10
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 135.73
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 94.67
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  94.67
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  135.73
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -139.36
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -139.36
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -44.10
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 328.50
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  328.50
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 400.50
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 390.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  390.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  400.50
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  312.62
# |   |   |   |   |   |   |--- REL_HEADING <= -116.82
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -116.82
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |--- GROUNDSPEED_KTS >  415.50
# |   |   |   |   |--- DIST_TO_DEST <= 320.43
# |   |   |   |   |   |--- REL_HEADING <= -58.82
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 305.55
# |   |   |   |   |   |   |   |--- REL_HEADING <= -59.82
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- REL_HEADING >  -59.82
# |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |--- DIST_TO_DEST >  305.55
# |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |--- REL_HEADING >  -58.82
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  320.43
# |   |   |   |   |   |--- DIST_TO_DEST <= 321.36
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  321.36
# |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |--- REL_HEADING >  -27.08
# |   |   |   |--- GROUNDSPEED_KTS <= 410.50
# |   |   |   |   |--- REL_HEADING <= 8.01
# |   |   |   |   |   |--- DIST_TO_DEST <= 163.13
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 113.78
# |   |   |   |   |   |   |   |--- REL_HEADING <= -23.06
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 111.58
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 69.99
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  69.99
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  111.58
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- REL_HEADING >  -23.06
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 82.78
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -21.83
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -21.83
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  82.78
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 360.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  360.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |--- DIST_TO_DEST >  113.78
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 134.27
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 357.50
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  357.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 125.64
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  125.64
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  134.27
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 394.50
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -0.67
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -0.67
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  394.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 153.42
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  153.42
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |--- DIST_TO_DEST >  163.13
# |   |   |   |   |   |   |--- REL_HEADING <= -9.67
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 244.69
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  244.69
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -9.67
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 167.33
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  167.33
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 259.48
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 257.77
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  257.77
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  259.48
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |--- REL_HEADING >  8.01
# |   |   |   |   |   |--- DIST_TO_DEST <= 118.37
# |   |   |   |   |   |   |--- REL_HEADING <= 26.73
# |   |   |   |   |   |   |   |--- REL_HEADING <= 26.25
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 96.90
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 398.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  398.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  96.90
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 361.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  361.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- REL_HEADING >  26.25
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 60.61
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  60.61
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- REL_HEADING >  26.73
# |   |   |   |   |   |   |   |--- REL_HEADING <= 66.66
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 58.46
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 50.85
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  50.85
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  58.46
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 66.78
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  66.78
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- REL_HEADING >  66.66
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 331.50
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  331.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 56.02
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  56.02
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |--- DIST_TO_DEST >  118.37
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 152.35
# |   |   |   |   |   |   |   |--- REL_HEADING <= 22.31
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 132.32
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 119.75
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  119.75
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  132.32
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- REL_HEADING >  22.31
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 128.99
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  128.99
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 131.75
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  131.75
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- DIST_TO_DEST >  152.35
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |--- GROUNDSPEED_KTS >  410.50
# |   |   |   |   |--- REL_HEADING <= -19.71
# |   |   |   |   |   |--- DIST_TO_DEST <= 232.10
# |   |   |   |   |   |   |--- REL_HEADING <= -25.51
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 163.82
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  163.82
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 166.86
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  166.86
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- REL_HEADING >  -25.51
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 156.45
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  156.45
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -20.58
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 170.01
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  170.01
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -20.58
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 211.03
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  211.03
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |--- DIST_TO_DEST >  232.10
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 254.45
# |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- DIST_TO_DEST >  254.45
# |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |--- REL_HEADING >  -19.71
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 484.50
# |   |   |   |   |   |   |--- REL_HEADING <= -2.51
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 496.92
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 244.65
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -5.38
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -5.38
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  244.65
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 304.83
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  304.83
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  496.92
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 558.76
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  558.76
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -3.0DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -2.51
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 428.50
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 123.03
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 4.52
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  4.52
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  123.03
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 227.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  227.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  428.50
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 66.18
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 9.64
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  9.64
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  66.18
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 99.33
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  99.33
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  484.50
# |   |   |   |   |   |   |--- REL_HEADING <= 49.92
# |   |   |   |   |   |   |   |--- REL_HEADING <= 28.99
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 101.51
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 100.02
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  100.02
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  101.51
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- REL_HEADING >  28.99
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 49.72
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  49.72
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |--- REL_HEADING >  49.92
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |--- REL_HEADING >  67.75
# |   |   |--- REL_HEADING <= 141.62
# |   |   |   |--- DIST_TO_DEST <= 140.87
# |   |   |   |   |--- DIST_TO_DEST <= 62.77
# |   |   |   |   |   |--- REL_HEADING <= 79.64
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- REL_HEADING >  79.64
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  62.77
# |   |   |   |   |   |--- DIST_TO_DEST <= 89.41
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 68.34
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  68.34
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  89.41
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |--- DIST_TO_DEST >  140.87
# |   |   |   |   |--- DIST_TO_DEST <= 309.77
# |   |   |   |   |   |--- REL_HEADING <= 137.77
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- REL_HEADING >  137.77
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  309.77
# |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |--- REL_HEADING >  141.62
# |   |   |   |--- DIST_TO_DEST <= 42.37
# |   |   |   |   |--- GROUNDSPEED_KTS <= 338.50
# |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |--- GROUNDSPEED_KTS >  338.50
# |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |--- DIST_TO_DEST >  42.37
# |   |   |   |   |--- DIST_TO_DEST <= 306.30
# |   |   |   |   |   |--- DIST_TO_DEST <= 115.28
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 89.98
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- DIST_TO_DEST >  89.98
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  115.28
# |   |   |   |   |   |   |--- REL_HEADING <= 148.72
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  148.72
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- DIST_TO_DEST >  306.30
# |   |   |   |   |   |--- DIST_TO_DEST <= 311.67
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  311.67
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec

# %%
# Entropy, large tree with train data

criterion = "entropy"
dtree_large_n = DecisionTreeClassifier(criterion=criterion, min_samples_leaf=20)   # (random_state=1234)
model=dtree_large_n.fit(X_df,Y)
res = np.array(model.predict(X_df))
diff = res - Y
accuracy = 1/len(res) * sum([1 for x in diff if x == 0])
print(accuracy)
r = export_text(dtree_large_n, feature_names=list(X_df.columns), class_names=target_names, show_weights=False)
print(r)
viz_model = dtreeviz.model(dtree_large_n, X_df, Y,
                target_name="target",
                feature_names=list(X_df.columns),
                class_names=target_names)

v = viz_model.view()     # render as SVG into internal object 
v                 # pop up window
v.save(f"{data_name}_all_{Target_category_name}_{criterion}_without_xy_" + f"max_depth:{max_depth}"  + ".svg")  # optionally save as svg
# Out:
# 0.9562213670514935
# |--- GROUNDSPEED_KTS <= 320.50
# |   |--- REL_HEADING <= -120.14
# |   |   |--- REL_HEADING <= -142.00
# |   |   |   |--- DIST_TO_DEST <= 70.47
# |   |   |   |   |--- DIST_TO_DEST <= 32.28
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 199.50
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 187.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= -144.70
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- REL_HEADING >  -144.70
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  187.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= -154.30
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 4.04
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  4.04
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- REL_HEADING >  -154.30
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  199.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 30.79
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- DIST_TO_DEST >  30.79
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 31.53
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  31.53
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- DIST_TO_DEST >  32.28
# |   |   |   |   |   |--- DIST_TO_DEST <= 34.00
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 257.00
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  257.00
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 267.00
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  267.00
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 33.09
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  33.09
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  34.00
# |   |   |   |   |   |   |--- REL_HEADING <= -171.16
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 308.50
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  308.50
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  -171.16
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 61.76
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 43.25
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 40.26
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  40.26
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  43.25
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 59.59
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -157.56
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -157.56
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  59.59
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  61.76
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |--- DIST_TO_DEST >  70.47
# |   |   |   |   |--- DIST_TO_DEST <= 243.94
# |   |   |   |   |   |--- REL_HEADING <= -151.86
# |   |   |   |   |   |   |--- REL_HEADING <= -154.75
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -154.75
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- REL_HEADING >  -151.86
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  243.94
# |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |--- REL_HEADING >  -142.00
# |   |   |   |--- GROUNDSPEED_KTS <= 264.50
# |   |   |   |   |--- REL_HEADING <= -126.08
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 246.50
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  246.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 33.42
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 31.96
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  31.96
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  33.42
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- REL_HEADING >  -126.08
# |   |   |   |   |   |--- DIST_TO_DEST <= 32.04
# |   |   |   |   |   |   |--- REL_HEADING <= -120.17
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 24.85
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  24.85
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -120.17
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- DIST_TO_DEST >  32.04
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 50.01
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- DIST_TO_DEST >  50.01
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 52.42
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  52.42
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |--- GROUNDSPEED_KTS >  264.50
# |   |   |   |   |--- GROUNDSPEED_KTS <= 277.50
# |   |   |   |   |   |--- DIST_TO_DEST <= 51.63
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 39.09
# |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |--- DIST_TO_DEST >  39.09
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 50.93
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 269.50
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  269.50
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  50.93
# |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |--- DIST_TO_DEST >  51.63
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- GROUNDSPEED_KTS >  277.50
# |   |   |   |   |   |--- DIST_TO_DEST <= 66.47
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 58.57
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  58.57
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  66.47
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |--- REL_HEADING >  -120.14
# |   |   |--- REL_HEADING <= 120.50
# |   |   |   |--- GROUNDSPEED_KTS <= 180.50
# |   |   |   |   |--- DIST_TO_DEST <= 19.94
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 1.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.04
# |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- DIST_TO_DEST >  0.04
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.04
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.04
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -4.88
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.13
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -15.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -15.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.13
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.14
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.14
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -4.88
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  1.50
# |   |   |   |   |   |   |--- REL_HEADING <= 5.83
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 22.50
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.00
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.20
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -11.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -11.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.20
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -5.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -5.08
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  22.50
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 13.13
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  13.13
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -14.87
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -14.87
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -12.64
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -12.64
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- REL_HEADING >  5.83
# |   |   |   |   |   |   |   |--- REL_HEADING <= 88.33
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.18
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.08
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.08
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.18
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.20
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 58.99
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  58.99
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.20
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- REL_HEADING >  88.33
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 103.20
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.37
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.07
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.37
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  103.20
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.17
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -3.0DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.17
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |--- DIST_TO_DEST >  19.94
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 177.50
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 174.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 20.81
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  20.81
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  174.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 35.54
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 35.39
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  35.39
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  35.54
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  177.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 35.56
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 21.57
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  21.57
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- DIST_TO_DEST >  35.56
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 38.08
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 36.40
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  36.40
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 37.27
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  37.27
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  38.08
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |--- GROUNDSPEED_KTS >  180.50
# |   |   |   |   |--- REL_HEADING <= -61.49
# |   |   |   |   |   |--- DIST_TO_DEST <= 59.61
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 225.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 10.88
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  10.88
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 3.0DegPerSec
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  225.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= -67.97
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- REL_HEADING >  -67.97
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 31.25
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  31.25
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 37.09
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  37.09
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  59.61
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 67.08
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  67.08
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 95.19
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  95.19
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  -61.49
# |   |   |   |   |   |--- REL_HEADING <= 60.94
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 288.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 14.88
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 214.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 11.90
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 184.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  184.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  11.90
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 14.10
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  14.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  214.50
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 20.52
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 255.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  255.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  20.52
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 9.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  9.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  14.88
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -30.16
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 49.12
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 217.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  217.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  49.12
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 57.83
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  57.83
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -30.16
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 279.50
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 39.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  39.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  279.50
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -26.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -26.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  288.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= 13.35
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 312.50
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 3.11
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 43.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  43.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  3.11
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 41.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  41.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  312.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 43.91
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 42.79
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  42.79
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  43.91
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 7.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  7.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- REL_HEADING >  13.35
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 39.38
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 37.46
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  37.46
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  39.38
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 310.50
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 44.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  44.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  310.50
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 47.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  47.33
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- REL_HEADING >  60.94
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 252.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 21.99
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 238.50
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 237.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  237.50
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 14.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  14.49
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  238.50
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 70.44
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  70.44
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  21.99
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 223.50
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  223.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 45.80
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  45.80
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 47.10
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  47.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  252.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 45.78
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 307.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 42.86
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  42.86
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 45.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  45.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  307.50
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  45.78
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 78.00
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 77.92
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  77.92
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  78.00
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |--- REL_HEADING >  120.50
# |   |   |   |--- GROUNDSPEED_KTS <= 257.50
# |   |   |   |   |--- REL_HEADING <= 148.09
# |   |   |   |   |   |--- DIST_TO_DEST <= 44.21
# |   |   |   |   |   |   |--- REL_HEADING <= 134.29
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  134.29
# |   |   |   |   |   |   |   |--- REL_HEADING <= 142.42
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- REL_HEADING >  142.42
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- DIST_TO_DEST >  44.21
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- REL_HEADING >  148.09
# |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |--- GROUNDSPEED_KTS >  257.50
# |   |   |   |   |--- REL_HEADING <= 162.84
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 311.50
# |   |   |   |   |   |   |--- REL_HEADING <= 149.73
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 262.50
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  262.50
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  149.73
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 300.50
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 160.23
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 51.80
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  51.80
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  160.23
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  300.50
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  311.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 53.10
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  53.10
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  162.84
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 308.50
# |   |   |   |   |   |   |--- REL_HEADING <= 166.33
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  166.33
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  308.50
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |--- GROUNDSPEED_KTS >  320.50
# |   |--- REL_HEADING <= 67.75
# |   |   |--- REL_HEADING <= -27.08
# |   |   |   |--- GROUNDSPEED_KTS <= 415.50
# |   |   |   |   |--- REL_HEADING <= -143.93
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 411.50
# |   |   |   |   |   |   |--- REL_HEADING <= -172.36
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  -172.36
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 136.06
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  136.06
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 238.42
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  238.42
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 317.45
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  317.45
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  411.50
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  -143.93
# |   |   |   |   |   |--- DIST_TO_DEST <= 312.62
# |   |   |   |   |   |   |--- REL_HEADING <= -44.10
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 135.73
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 94.67
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  94.67
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  135.73
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -139.36
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -139.36
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -44.10
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 328.50
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  328.50
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 400.50
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 390.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  390.50
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -35.71
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -35.71
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  400.50
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  312.62
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 323.24
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  323.24
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |--- GROUNDSPEED_KTS >  415.50
# |   |   |   |   |--- DIST_TO_DEST <= 320.43
# |   |   |   |   |   |--- REL_HEADING <= -58.82
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 305.55
# |   |   |   |   |   |   |   |--- REL_HEADING <= -59.82
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- REL_HEADING >  -59.82
# |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |--- DIST_TO_DEST >  305.55
# |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |--- REL_HEADING >  -58.82
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  320.43
# |   |   |   |   |   |--- REL_HEADING <= -62.82
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- REL_HEADING >  -62.82
# |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |--- REL_HEADING >  -27.08
# |   |   |   |--- GROUNDSPEED_KTS <= 410.50
# |   |   |   |   |--- REL_HEADING <= 8.01
# |   |   |   |   |   |--- DIST_TO_DEST <= 163.13
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 113.78
# |   |   |   |   |   |   |   |--- REL_HEADING <= -23.06
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 111.58
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 69.99
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 69.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  69.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  69.99
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  111.58
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- REL_HEADING >  -23.06
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 82.78
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -21.83
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 2.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  2.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -21.83
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 3.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  3.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  82.78
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 360.50
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 108.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  108.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  360.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |--- DIST_TO_DEST >  113.78
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 134.27
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 357.50
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  357.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 125.64
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  125.64
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 127.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  127.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  134.27
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 394.50
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -0.67
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -1.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -1.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -0.67
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  394.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 153.42
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 138.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  138.49
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  153.42
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -13.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -13.28
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |--- DIST_TO_DEST >  163.13
# |   |   |   |   |   |   |--- REL_HEADING <= -9.67
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 244.69
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  244.69
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -9.67
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 167.33
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  167.33
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 259.48
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 257.77
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -8.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -8.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  257.77
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  259.48
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |--- REL_HEADING >  8.01
# |   |   |   |   |   |--- DIST_TO_DEST <= 118.37
# |   |   |   |   |   |   |--- REL_HEADING <= 26.73
# |   |   |   |   |   |   |   |--- REL_HEADING <= 26.25
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 96.90
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 398.00
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 44.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  44.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  398.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  96.90
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 361.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  361.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- REL_HEADING >  26.25
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 60.61
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  60.61
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- REL_HEADING >  26.73
# |   |   |   |   |   |   |   |--- REL_HEADING <= 66.66
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 58.46
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 50.85
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  50.85
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  58.46
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 66.78
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 375.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  375.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  66.78
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 28.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  28.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- REL_HEADING >  66.66
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 331.50
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  331.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 56.02
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  56.02
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 400.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  400.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |--- DIST_TO_DEST >  118.37
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 152.35
# |   |   |   |   |   |   |   |--- REL_HEADING <= 22.31
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 132.32
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 119.75
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  119.75
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  132.32
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- REL_HEADING >  22.31
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 128.99
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  128.99
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 131.75
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  131.75
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- DIST_TO_DEST >  152.35
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |--- GROUNDSPEED_KTS >  410.50
# |   |   |   |   |--- REL_HEADING <= -19.71
# |   |   |   |   |   |--- DIST_TO_DEST <= 232.10
# |   |   |   |   |   |   |--- REL_HEADING <= -25.51
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 163.82
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  163.82
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 166.86
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  166.86
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- REL_HEADING >  -25.51
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 156.45
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  156.45
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -20.58
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 170.01
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 168.46
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  168.46
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  170.01
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -20.58
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 211.03
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  211.03
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |--- DIST_TO_DEST >  232.10
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 254.45
# |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- DIST_TO_DEST >  254.45
# |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |--- REL_HEADING >  -19.71
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 484.50
# |   |   |   |   |   |   |--- REL_HEADING <= -2.51
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 496.92
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 244.65
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -5.38
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 214.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  214.41
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -5.38
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 157.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  157.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  244.65
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 304.83
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 303.33
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  303.33
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  304.83
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  496.92
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 558.76
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  558.76
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -3.0DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -2.51
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 428.50
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 123.03
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 4.52
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  4.52
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 90.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  90.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  123.03
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 227.50
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 152.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  152.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  227.50
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 309.52
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  309.52
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  428.50
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 66.18
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 9.64
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 7.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  7.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  9.64
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 456.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  456.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  66.18
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 99.33
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  99.33
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 133.74
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  133.74
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  484.50
# |   |   |   |   |   |   |--- REL_HEADING <= 49.92
# |   |   |   |   |   |   |   |--- REL_HEADING <= 28.99
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 101.51
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 100.02
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  100.02
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  101.51
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- REL_HEADING >  28.99
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 286.25
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  286.25
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |--- REL_HEADING >  49.92
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |--- REL_HEADING >  67.75
# |   |   |--- REL_HEADING <= 141.62
# |   |   |   |--- DIST_TO_DEST <= 140.87
# |   |   |   |   |--- DIST_TO_DEST <= 62.77
# |   |   |   |   |   |--- REL_HEADING <= 79.64
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- REL_HEADING >  79.64
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  62.77
# |   |   |   |   |   |--- DIST_TO_DEST <= 89.41
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 68.34
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  68.34
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  89.41
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |--- DIST_TO_DEST >  140.87
# |   |   |   |   |--- DIST_TO_DEST <= 309.77
# |   |   |   |   |   |--- REL_HEADING <= 137.77
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- REL_HEADING >  137.77
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  309.77
# |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |--- REL_HEADING >  141.62
# |   |   |   |--- DIST_TO_DEST <= 42.37
# |   |   |   |   |--- GROUNDSPEED_KTS <= 338.50
# |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |--- GROUNDSPEED_KTS >  338.50
# |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |--- DIST_TO_DEST >  42.37
# |   |   |   |   |--- DIST_TO_DEST <= 306.30
# |   |   |   |   |   |--- DIST_TO_DEST <= 115.28
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 89.98
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- DIST_TO_DEST >  89.98
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  115.28
# |   |   |   |   |   |   |--- REL_HEADING <= 148.72
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  148.72
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- DIST_TO_DEST >  306.30
# |   |   |   |   |   |--- DIST_TO_DEST <= 311.67
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  311.67
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# /Users/binshuaiwang/PycharmProjects/XAI_project/venv/lib/python3.10/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names

# %%
# Entropy, large tree with test data

criterion = "entropy"
dtree_large_entropy = DecisionTreeClassifier(criterion=criterion)   # (random_state=1234)
model=dtree_large_entropy.fit(X_df,Y)
res = np.array(model.predict(X_df_test))
diff = res - Z
accuracy = 1/len(res) * sum([1 for x in diff if x == 0])
print(accuracy)
r = export_text(dtree_large_entropy, feature_names=list(X_df.columns), class_names=target_names, show_weights=False)
print(r)
# Out:
# 0.9999999999999999
# |--- GROUNDSPEED_KTS <= 320.50
# |   |--- REL_HEADING <= -120.14
# |   |   |--- REL_HEADING <= -142.00
# |   |   |   |--- DIST_TO_DEST <= 70.47
# |   |   |   |   |--- DIST_TO_DEST <= 32.28
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 199.50
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 187.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= -144.70
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- REL_HEADING >  -144.70
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -142.31
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 3.0DegPerSec
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -142.31
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  187.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= -154.30
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 4.04
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 4.01
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  4.01
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 4.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  4.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  4.04
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- REL_HEADING >  -154.30
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -146.48
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -150.98
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 21.52
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  21.52
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -150.98
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 21.92
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  21.92
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -146.48
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  199.50
# |   |   |   |   |   |   |--- REL_HEADING <= -142.17
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  -142.17
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 258.50
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  258.50
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- DIST_TO_DEST >  32.28
# |   |   |   |   |   |--- DIST_TO_DEST <= 34.00
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 257.00
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  257.00
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 267.00
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  267.00
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 292.00
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  292.00
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- DIST_TO_DEST >  34.00
# |   |   |   |   |   |   |--- REL_HEADING <= -171.16
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 311.50
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  311.50
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -171.16
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 61.76
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 43.25
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 40.26
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 39.94
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  39.94
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  40.26
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  43.25
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 59.59
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -157.56
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -157.56
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  59.59
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -151.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -151.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  61.76
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |--- DIST_TO_DEST >  70.47
# |   |   |   |   |--- DIST_TO_DEST <= 243.94
# |   |   |   |   |   |--- REL_HEADING <= -151.86
# |   |   |   |   |   |   |--- REL_HEADING <= -154.75
# |   |   |   |   |   |   |   |--- REL_HEADING <= -176.69
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- REL_HEADING >  -176.69
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -154.75
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 71.25
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 290.50
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  290.50
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  71.25
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- REL_HEADING >  -151.86
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  243.94
# |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |--- REL_HEADING >  -142.00
# |   |   |   |--- GROUNDSPEED_KTS <= 264.50
# |   |   |   |   |--- REL_HEADING <= -126.08
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 188.50
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 5.50
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -3.0DegPerSec
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  5.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 10.64
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -135.70
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -135.70
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  10.64
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  188.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 35.34
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 238.00
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 22.24
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  22.24
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 209.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  209.50
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -135.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -135.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  238.00
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 257.50
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  257.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 31.69
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  31.69
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -137.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -137.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- DIST_TO_DEST >  35.34
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 248.50
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  248.50
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- REL_HEADING >  -126.08
# |   |   |   |   |   |--- DIST_TO_DEST <= 32.04
# |   |   |   |   |   |   |--- REL_HEADING <= -120.17
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 28.39
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 24.52
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 198.00
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -122.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -122.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  198.00
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 14.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  14.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  24.52
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  28.39
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 31.94
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  31.94
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -125.17
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -125.17
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -123.67
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -123.67
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -120.17
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- DIST_TO_DEST >  32.04
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 50.01
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- DIST_TO_DEST >  50.01
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 52.29
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 52.11
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  52.11
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  52.29
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |--- GROUNDSPEED_KTS >  264.50
# |   |   |   |   |--- GROUNDSPEED_KTS <= 277.50
# |   |   |   |   |   |--- DIST_TO_DEST <= 51.63
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 38.30
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 270.50
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  270.50
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  38.30
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 51.44
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 265.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 48.01
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  48.01
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  265.50
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  51.44
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -123.67
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -123.67
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- DIST_TO_DEST >  51.63
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 52.12
# |   |   |   |   |   |   |   |--- REL_HEADING <= -124.17
# |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- REL_HEADING >  -124.17
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 51.66
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  51.66
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  52.12
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 52.37
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -123.17
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -123.17
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  52.37
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- GROUNDSPEED_KTS >  277.50
# |   |   |   |   |   |--- DIST_TO_DEST <= 66.47
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 59.87
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  59.87
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  66.47
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |--- REL_HEADING >  -120.14
# |   |   |--- REL_HEADING <= 120.50
# |   |   |   |--- GROUNDSPEED_KTS <= 180.50
# |   |   |   |   |--- DIST_TO_DEST <= 19.94
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 1.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.04
# |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- DIST_TO_DEST >  0.04
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.04
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.04
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.04
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.04
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -4.88
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.13
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -15.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -15.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.13
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.13
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -4.88
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  1.50
# |   |   |   |   |   |   |--- REL_HEADING <= 5.83
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 22.50
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.00
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.20
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -11.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -11.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.20
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -5.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -5.08
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  22.50
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 13.13
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  13.13
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -14.87
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -14.87
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -12.64
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -12.64
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- REL_HEADING >  5.83
# |   |   |   |   |   |   |   |--- REL_HEADING <= 88.33
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.18
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.08
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.08
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 45.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  45.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.18
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.20
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 58.99
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  58.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.20
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |--- REL_HEADING >  88.33
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 103.20
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.37
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 90.42
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  90.42
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.37
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.38
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  103.20
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 107.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  107.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |--- DIST_TO_DEST >  19.94
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 177.50
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 174.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 21.09
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  21.09
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -66.41
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 35.52
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  35.52
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -3.0DegPerSec
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -66.41
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 28.24
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -3.0DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  28.24
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  174.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= -75.91
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 35.82
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -3.0DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  35.82
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 36.12
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  36.12
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- REL_HEADING >  -75.91
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -25.41
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -25.41
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 15.73
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  15.73
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 27.36
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -3.0DegPerSec
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  27.36
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  177.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 35.56
# |   |   |   |   |   |   |   |--- REL_HEADING <= 18.73
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 28.97
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  28.97
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 35.54
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  35.54
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- REL_HEADING >  18.73
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  35.56
# |   |   |   |   |   |   |   |--- REL_HEADING <= -78.41
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 37.56
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  37.56
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 38.08
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  38.08
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- REL_HEADING >  -78.41
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |--- GROUNDSPEED_KTS >  180.50
# |   |   |   |   |--- REL_HEADING <= -61.49
# |   |   |   |   |   |--- DIST_TO_DEST <= 59.61
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 225.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 7.97
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 2.39
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.10
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -3.0DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.10
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  2.39
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  7.97
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 223.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 10.86
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  10.86
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 3.0DegPerSec
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  223.50
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  225.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= -67.97
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- REL_HEADING >  -67.97
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 31.13
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 30.85
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -63.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -63.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  30.85
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  31.13
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 55.08
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  55.08
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |--- DIST_TO_DEST >  59.61
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 291.50
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  291.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 95.19
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  95.19
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -104.02
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -104.02
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  -61.49
# |   |   |   |   |   |--- REL_HEADING <= 60.94
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 288.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 14.88
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 214.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 11.90
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 184.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  184.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  11.90
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 14.10
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  14.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  214.50
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 20.52
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 255.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  255.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  20.52
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 232.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  232.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  14.88
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -30.16
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 49.12
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 217.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  217.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  49.12
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 57.83
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  57.83
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -30.16
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 279.50
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 39.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  39.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 30
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  279.50
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -26.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -26.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  288.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= 13.35
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 312.50
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 3.11
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 43.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  43.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  3.11
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 41.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  41.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  312.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 43.91
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -15.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -15.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  43.91
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 7.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  7.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- REL_HEADING >  13.35
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 39.38
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 293.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  293.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  39.38
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 310.50
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 44.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  44.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  310.50
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 47.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  47.33
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- REL_HEADING >  60.94
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 252.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 21.99
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 238.50
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 237.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  237.50
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 17.39
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  17.39
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  238.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 5.01
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  5.01
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 64.44
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  64.44
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  21.99
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 223.50
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  223.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 45.70
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 87.73
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  87.73
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  45.70
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 47.10
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  47.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  252.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 45.78
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 307.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 42.70
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 42.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  42.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 3.0DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  42.70
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 69.90
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  69.90
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  307.50
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  45.78
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 78.00
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 77.92
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  77.92
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  78.00
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |--- REL_HEADING >  120.50
# |   |   |   |--- GROUNDSPEED_KTS <= 257.50
# |   |   |   |   |--- REL_HEADING <= 148.09
# |   |   |   |   |   |--- DIST_TO_DEST <= 0.17
# |   |   |   |   |   |   |--- REL_HEADING <= 130.99
# |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- REL_HEADING >  130.99
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.15
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.15
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 3.0DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.15
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 3.0DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.15
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.16
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 3.0DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.16
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  0.17
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 44.21
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 44.10
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 142.22
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.30
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.30
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  142.22
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.29
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.29
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  44.10
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 3.0DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  44.21
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- REL_HEADING >  148.09
# |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |--- GROUNDSPEED_KTS >  257.50
# |   |   |   |   |--- REL_HEADING <= 162.84
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 311.50
# |   |   |   |   |   |   |--- REL_HEADING <= 149.73
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 259.50
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 73.65
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 45.53
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  45.53
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 59.59
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  59.59
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  73.65
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  259.50
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  149.73
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 300.50
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 261.00
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  261.00
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 48.52
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  48.52
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 161.94
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  161.94
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  300.50
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 59.90
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 307.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  307.00
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 59.58
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  59.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  59.90
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  311.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 53.10
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  53.10
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  162.84
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 308.50
# |   |   |   |   |   |   |--- REL_HEADING <= 164.84
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 48.21
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 44.81
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  44.81
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  48.21
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  164.84
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  308.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 48.75
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  48.75
# |   |   |   |   |   |   |   |--- REL_HEADING <= 168.81
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- REL_HEADING >  168.81
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |--- GROUNDSPEED_KTS >  320.50
# |   |--- REL_HEADING <= 67.75
# |   |   |--- REL_HEADING <= -27.08
# |   |   |   |--- GROUNDSPEED_KTS <= 415.50
# |   |   |   |   |--- REL_HEADING <= -143.93
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 411.50
# |   |   |   |   |   |   |--- REL_HEADING <= -172.36
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  -172.36
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 136.06
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 359.50
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  359.50
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  136.06
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 238.42
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  238.42
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 317.45
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  317.45
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  411.50
# |   |   |   |   |   |   |--- REL_HEADING <= -173.32
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  -173.32
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  -143.93
# |   |   |   |   |   |--- DIST_TO_DEST <= 312.62
# |   |   |   |   |   |   |--- REL_HEADING <= -44.10
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 135.73
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 94.67
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# ...
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  119.70
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  132.32
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 137.19
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 132.64
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  132.64
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  137.19
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- REL_HEADING >  22.31
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 128.59
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  128.59
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 132.84
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  132.84
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  152.35
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |--- GROUNDSPEED_KTS >  410.50
# |   |   |   |   |--- REL_HEADING <= -19.71
# |   |   |   |   |   |--- DIST_TO_DEST <= 232.10
# |   |   |   |   |   |   |--- REL_HEADING <= -25.51
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 160.80
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 156.54
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  156.54
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  160.80
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 168.37
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  168.37
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -25.51
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 156.45
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 424.50
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 418.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  418.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  424.50
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  156.45
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -20.58
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 170.01
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 169.23
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  169.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  170.01
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -20.58
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 210.91
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -20.08
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -20.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  210.91
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |--- DIST_TO_DEST >  232.10
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 255.65
# |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- DIST_TO_DEST >  255.65
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  -19.71
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 484.50
# |   |   |   |   |   |   |--- REL_HEADING <= -2.51
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 496.92
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 244.65
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -5.38
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 214.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  214.41
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -5.38
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 238.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  238.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  244.65
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 304.83
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 448.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  448.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  304.83
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  496.92
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 559.45
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  559.45
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 560.51
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 559.84
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  559.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  560.51
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 564.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  564.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |--- REL_HEADING >  -2.51
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 428.50
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 123.03
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 4.52
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 77.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  77.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  4.52
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 90.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  90.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  123.03
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 227.50
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 152.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  152.55
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  227.50
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 300.14
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  300.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  428.50
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 66.18
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 9.64
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 7.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  7.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  9.64
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 456.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  456.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  66.18
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 99.33
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  99.33
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 135.09
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  135.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  484.50
# |   |   |   |   |   |   |--- REL_HEADING <= 49.92
# |   |   |   |   |   |   |   |--- REL_HEADING <= 28.99
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 101.51
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -1.08
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 486.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  486.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -1.08
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 492.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  492.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  101.51
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- REL_HEADING >  28.99
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 286.25
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  286.25
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |--- REL_HEADING >  49.92
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |--- REL_HEADING >  67.75
# |   |   |--- REL_HEADING <= 141.62
# |   |   |   |--- DIST_TO_DEST <= 140.87
# |   |   |   |   |--- DIST_TO_DEST <= 62.77
# |   |   |   |   |   |--- DIST_TO_DEST <= 50.68
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  50.68
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  62.77
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 349.00
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 67.86
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- DIST_TO_DEST >  67.86
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  349.00
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 89.41
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 68.39
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 73.35
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  73.35
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  68.39
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 82.35
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  82.35
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- DIST_TO_DEST >  89.41
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |--- DIST_TO_DEST >  140.87
# |   |   |   |   |--- DIST_TO_DEST <= 309.77
# |   |   |   |   |   |--- REL_HEADING <= 140.92
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- REL_HEADING >  140.92
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 435.50
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  435.50
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  309.77
# |   |   |   |   |   |--- REL_HEADING <= 132.18
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- REL_HEADING >  132.18
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |--- REL_HEADING >  141.62
# |   |   |   |--- DIST_TO_DEST <= 42.37
# |   |   |   |   |--- GROUNDSPEED_KTS <= 332.50
# |   |   |   |   |   |--- REL_HEADING <= 162.14
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- REL_HEADING >  162.14
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |--- GROUNDSPEED_KTS >  332.50
# |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |--- DIST_TO_DEST >  42.37
# |   |   |   |   |--- DIST_TO_DEST <= 306.30
# |   |   |   |   |   |--- DIST_TO_DEST <= 115.28
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 89.98
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- DIST_TO_DEST >  89.98
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  115.28
# |   |   |   |   |   |   |--- REL_HEADING <= 148.72
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 175.50
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 172.85
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 365.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  365.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  172.85
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  175.50
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  148.72
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- DIST_TO_DEST >  306.30
# |   |   |   |   |   |--- DIST_TO_DEST <= 309.89
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  309.89
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 314.52
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  314.52
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course

# %%
# Entropy, small tree with test data

criterion = "entropy"
dtree_small_entropy = DecisionTreeClassifier(criterion=criterion, max_depth=10, min_samples_leaf=20)   # (random_state=1234)
model=dtree_small_entropy.fit(X_df,Y)
res = np.array(model.predict(X_df_test))
diff = res - Z
accuracy = 1/len(res) * sum([1 for x in diff if x == 0])
print(accuracy)
r = export_text(dtree_small_entropy, feature_names=list(X_df.columns), class_names=target_names, show_weights=False)
print(r)
# Out:
# 0.6777223363663046
# |--- GROUNDSPEED_KTS <= 320.50
# |   |--- REL_HEADING <= -120.14
# |   |   |--- REL_HEADING <= -142.00
# |   |   |   |--- DIST_TO_DEST <= 70.47
# |   |   |   |   |--- DIST_TO_DEST <= 32.28
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 199.50
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 187.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= -144.70
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- REL_HEADING >  -144.70
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  187.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= -154.30
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 4.04
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  4.04
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- REL_HEADING >  -154.30
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  199.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 30.79
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- DIST_TO_DEST >  30.79
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 31.53
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  31.53
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- DIST_TO_DEST >  32.28
# |   |   |   |   |   |--- DIST_TO_DEST <= 34.00
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 257.00
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  257.00
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 267.00
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  267.00
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 33.09
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  33.09
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  34.00
# |   |   |   |   |   |   |--- REL_HEADING <= -171.16
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 308.50
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  308.50
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  -171.16
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 61.76
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 43.25
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 40.26
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  40.26
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  43.25
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 59.59
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  59.59
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  61.76
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |--- DIST_TO_DEST >  70.47
# |   |   |   |   |--- DIST_TO_DEST <= 243.94
# |   |   |   |   |   |--- REL_HEADING <= -151.86
# |   |   |   |   |   |   |--- REL_HEADING <= -154.75
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -154.75
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- REL_HEADING >  -151.86
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  243.94
# |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |--- REL_HEADING >  -142.00
# |   |   |   |--- GROUNDSPEED_KTS <= 264.50
# |   |   |   |   |--- REL_HEADING <= -126.08
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 246.50
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  246.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 33.42
# |   |   |   |   |   |   |   |--- REL_HEADING <= -133.17
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- REL_HEADING >  -133.17
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  33.42
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- REL_HEADING >  -126.08
# |   |   |   |   |   |--- DIST_TO_DEST <= 32.04
# |   |   |   |   |   |   |--- REL_HEADING <= -120.17
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 24.85
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  24.85
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -120.17
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- DIST_TO_DEST >  32.04
# |   |   |   |   |   |   |--- REL_HEADING <= -125.60
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 52.42
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  52.42
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  -125.60
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |--- GROUNDSPEED_KTS >  264.50
# |   |   |   |   |--- GROUNDSPEED_KTS <= 277.50
# |   |   |   |   |   |--- DIST_TO_DEST <= 51.63
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 39.09
# |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |--- DIST_TO_DEST >  39.09
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 50.93
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 269.50
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  269.50
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  50.93
# |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |--- DIST_TO_DEST >  51.63
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- GROUNDSPEED_KTS >  277.50
# |   |   |   |   |   |--- DIST_TO_DEST <= 66.47
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 58.57
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  58.57
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  66.47
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |--- REL_HEADING >  -120.14
# |   |   |--- REL_HEADING <= 120.50
# |   |   |   |--- GROUNDSPEED_KTS <= 180.50
# |   |   |   |   |--- DIST_TO_DEST <= 19.94
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 1.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.04
# |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- DIST_TO_DEST >  0.04
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.04
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.04
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -4.88
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.13
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.13
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -4.88
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  1.50
# |   |   |   |   |   |   |--- REL_HEADING <= 5.83
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 22.50
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.00
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.20
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.20
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  22.50
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 13.13
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  13.13
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -14.87
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -14.87
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- REL_HEADING >  5.83
# |   |   |   |   |   |   |   |--- REL_HEADING <= 88.33
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.18
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.08
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.08
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.18
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.20
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.20
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- REL_HEADING >  88.33
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 103.20
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.37
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.37
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  103.20
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 0.17
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -3.0DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  0.17
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |--- DIST_TO_DEST >  19.94
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 177.50
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 174.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 20.81
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  20.81
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  174.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 35.54
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 35.39
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  35.39
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  35.54
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  177.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 35.56
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 21.57
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  21.57
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- DIST_TO_DEST >  35.56
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 38.08
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 36.40
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  36.40
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 37.27
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  37.27
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  38.08
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |--- GROUNDSPEED_KTS >  180.50
# |   |   |   |   |--- REL_HEADING <= -61.49
# |   |   |   |   |   |--- DIST_TO_DEST <= 59.61
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 225.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 10.88
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  10.88
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 3.0DegPerSec
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  225.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= -67.97
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- REL_HEADING >  -67.97
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 31.25
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  31.25
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 37.09
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  37.09
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  59.61
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 291.50
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  291.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 95.19
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  95.19
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  -61.49
# |   |   |   |   |   |--- REL_HEADING <= 60.94
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 288.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 14.88
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 214.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 11.90
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  11.90
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  214.50
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 20.52
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  20.52
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  14.88
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -30.16
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 49.12
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  49.12
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -30.16
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 279.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  279.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  288.50
# |   |   |   |   |   |   |   |--- REL_HEADING <= 13.35
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 312.50
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 3.11
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  3.11
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  312.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 43.91
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  43.91
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- REL_HEADING >  13.35
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 39.38
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 37.46
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  37.46
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  39.38
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 310.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  310.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- REL_HEADING >  60.94
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 252.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 21.99
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 238.50
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 237.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  237.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  238.50
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 70.44
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  70.44
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  21.99
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 223.50
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  223.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 45.80
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  45.80
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  252.50
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 45.78
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 307.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 42.86
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  42.86
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  307.50
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  45.78
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 78.00
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 77.92
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  77.92
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  78.00
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |--- REL_HEADING >  120.50
# |   |   |   |--- GROUNDSPEED_KTS <= 257.50
# |   |   |   |   |--- REL_HEADING <= 148.09
# |   |   |   |   |   |--- DIST_TO_DEST <= 44.21
# |   |   |   |   |   |   |--- REL_HEADING <= 134.29
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  134.29
# |   |   |   |   |   |   |   |--- REL_HEADING <= 142.42
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- REL_HEADING >  142.42
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- DIST_TO_DEST >  44.21
# |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- REL_HEADING >  148.09
# |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |--- GROUNDSPEED_KTS >  257.50
# |   |   |   |   |--- REL_HEADING <= 162.84
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 311.50
# |   |   |   |   |   |   |--- REL_HEADING <= 149.73
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 262.50
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  262.50
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  149.73
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 300.50
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 160.23
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 51.80
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  51.80
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  160.23
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  300.50
# |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  311.50
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 53.10
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  53.10
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  162.84
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 308.50
# |   |   |   |   |   |   |--- REL_HEADING <= 166.33
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  166.33
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  308.50
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |--- GROUNDSPEED_KTS >  320.50
# |   |--- REL_HEADING <= 67.75
# |   |   |--- REL_HEADING <= -27.08
# |   |   |   |--- GROUNDSPEED_KTS <= 415.50
# |   |   |   |   |--- REL_HEADING <= -143.93
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 411.50
# |   |   |   |   |   |   |--- REL_HEADING <= -172.36
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  -172.36
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 136.06
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  136.06
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 238.42
# |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  238.42
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 317.45
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  317.45
# |   |   |   |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  411.50
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- REL_HEADING >  -143.93
# |   |   |   |   |   |--- DIST_TO_DEST <= 312.62
# |   |   |   |   |   |   |--- REL_HEADING <= -44.10
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 135.73
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 94.67
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  94.67
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  135.73
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -139.36
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -139.36
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -44.10
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 328.50
# |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  328.50
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 400.50
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 390.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  390.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  400.50
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  312.62
# |   |   |   |   |   |   |--- REL_HEADING <= -116.82
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -116.82
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |--- GROUNDSPEED_KTS >  415.50
# |   |   |   |   |--- DIST_TO_DEST <= 320.43
# |   |   |   |   |   |--- REL_HEADING <= -58.82
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 305.55
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 434.50
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  434.50
# |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |--- DIST_TO_DEST >  305.55
# |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |--- REL_HEADING >  -58.82
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  320.43
# |   |   |   |   |   |--- DIST_TO_DEST <= 321.36
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  321.36
# |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |--- REL_HEADING >  -27.08
# |   |   |   |--- GROUNDSPEED_KTS <= 410.50
# |   |   |   |   |--- REL_HEADING <= 8.01
# |   |   |   |   |   |--- DIST_TO_DEST <= 163.13
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 113.78
# |   |   |   |   |   |   |   |--- REL_HEADING <= -23.06
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 111.58
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 69.99
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  69.99
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  111.58
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- REL_HEADING >  -23.06
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 82.78
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -21.83
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -21.83
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  82.78
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 360.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  360.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |--- DIST_TO_DEST >  113.78
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 134.27
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 357.50
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  357.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 125.64
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  125.64
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  134.27
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 394.50
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -0.67
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -0.67
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  394.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 153.42
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  153.42
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |--- DIST_TO_DEST >  163.13
# |   |   |   |   |   |   |--- REL_HEADING <= -9.67
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 244.69
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  244.69
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -9.67
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 167.33
# |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  167.33
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 259.48
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 257.77
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  257.77
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  259.48
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |--- REL_HEADING >  8.01
# |   |   |   |   |   |--- DIST_TO_DEST <= 118.37
# |   |   |   |   |   |   |--- REL_HEADING <= 26.73
# |   |   |   |   |   |   |   |--- REL_HEADING <= 26.25
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 96.90
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 398.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  398.00
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  96.90
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 361.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  361.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- REL_HEADING >  26.25
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 60.61
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  60.61
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- REL_HEADING >  26.73
# |   |   |   |   |   |   |   |--- REL_HEADING <= 66.66
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 58.46
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 50.85
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  50.85
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  58.46
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 66.78
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  66.78
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- REL_HEADING >  66.66
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 331.50
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  331.50
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 56.02
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  56.02
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |--- DIST_TO_DEST >  118.37
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 152.35
# |   |   |   |   |   |   |   |--- REL_HEADING <= 22.31
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 132.32
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 119.75
# |   |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  119.75
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  132.32
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |   |--- REL_HEADING >  22.31
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 128.99
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  128.99
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 131.75
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  131.75
# |   |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- DIST_TO_DEST >  152.35
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |--- GROUNDSPEED_KTS >  410.50
# |   |   |   |   |--- REL_HEADING <= -19.71
# |   |   |   |   |   |--- DIST_TO_DEST <= 232.10
# |   |   |   |   |   |   |--- REL_HEADING <= -25.51
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 163.82
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  163.82
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 166.86
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  166.86
# |   |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- REL_HEADING >  -25.51
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 156.45
# |   |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  156.45
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= -20.58
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 170.01
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  170.01
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  -20.58
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 211.03
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  211.03
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |--- DIST_TO_DEST >  232.10
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 254.45
# |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |   |   |--- DIST_TO_DEST >  254.45
# |   |   |   |   |   |   |   |--- class:  No Conclusion: Horizontal
# |   |   |   |   |--- REL_HEADING >  -19.71
# |   |   |   |   |   |--- GROUNDSPEED_KTS <= 484.50
# |   |   |   |   |   |   |--- REL_HEADING <= -2.51
# |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 496.92
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 244.65
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= -5.38
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  -5.38
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  244.65
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 304.83
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  304.83
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- DIST_TO_DEST >  496.92
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 558.76
# |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  558.76
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -3.0DegPerSec
# |   |   |   |   |   |   |--- REL_HEADING >  -2.51
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS <= 428.50
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 123.03
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 4.52
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  4.52
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  123.03
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 227.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  227.50
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |   |   |--- GROUNDSPEED_KTS >  428.50
# |   |   |   |   |   |   |   |   |--- REL_HEADING <= 66.18
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING <= 9.64
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- REL_HEADING >  9.64
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- REL_HEADING >  66.18
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 99.33
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  99.33
# |   |   |   |   |   |   |   |   |   |   |--- class:  Fly Towards Destination
# |   |   |   |   |   |--- GROUNDSPEED_KTS >  484.50
# |   |   |   |   |   |   |--- REL_HEADING <= 49.92
# |   |   |   |   |   |   |   |--- REL_HEADING <= 28.99
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 101.51
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 100.02
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  100.02
# |   |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  101.51
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |   |--- REL_HEADING >  28.99
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST <= 286.25
# |   |   |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |   |   |   |--- DIST_TO_DEST >  286.25
# |   |   |   |   |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |   |   |--- REL_HEADING >  49.92
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |--- REL_HEADING >  67.75
# |   |   |--- REL_HEADING <= 141.62
# |   |   |   |--- DIST_TO_DEST <= 140.87
# |   |   |   |   |--- DIST_TO_DEST <= 62.77
# |   |   |   |   |   |--- DIST_TO_DEST <= 56.02
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  56.02
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  62.77
# |   |   |   |   |   |--- DIST_TO_DEST <= 89.41
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 68.34
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |   |--- DIST_TO_DEST >  68.34
# |   |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  89.41
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |--- DIST_TO_DEST >  140.87
# |   |   |   |   |--- DIST_TO_DEST <= 309.77
# |   |   |   |   |   |--- REL_HEADING <= 137.77
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- REL_HEADING >  137.77
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |--- DIST_TO_DEST >  309.77
# |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |--- REL_HEADING >  141.62
# |   |   |   |--- DIST_TO_DEST <= 42.37
# |   |   |   |   |--- DIST_TO_DEST <= 37.34
# |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |   |--- DIST_TO_DEST >  37.34
# |   |   |   |   |   |--- class:  Maintain Current Heading
# |   |   |   |--- DIST_TO_DEST >  42.37
# |   |   |   |   |--- DIST_TO_DEST <= 306.30
# |   |   |   |   |   |--- DIST_TO_DEST <= 115.28
# |   |   |   |   |   |   |--- DIST_TO_DEST <= 89.98
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- DIST_TO_DEST >  89.98
# |   |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  115.28
# |   |   |   |   |   |   |--- REL_HEADING <= 148.72
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |   |   |--- REL_HEADING >  148.72
# |   |   |   |   |   |   |   |--- class:  Flying opposite established course
# |   |   |   |   |--- DIST_TO_DEST >  306.30
# |   |   |   |   |   |--- DIST_TO_DEST <= 311.67
# |   |   |   |   |   |   |--- class:  Hold Left Turn -1.5DegPerSec
# |   |   |   |   |   |--- DIST_TO_DEST >  311.67
# |   |   |   |   |   |   |--- class:  Hold Right Turn 1.5DegPerSec

# %%
# Entropy, large rf with test data

criterion = "entropy"
num_of_trees = 3
rf_small_entropy = RandomForestClassifier(n_estimators=num_of_trees)
model=rf_small_entropy.fit(X_df,Y)
res = np.array(model.predict(X_df_test))
diff = res - Z
accuracy = 1/len(res) * sum([1 for x in diff if x == 0])
print(accuracy)
# Out:
# 0.9935427061931317

# %%
# Entropy, small rf with test data

criterion = "entropy"
num_of_trees = 3
rf_small_entropy = RandomForestClassifier(n_estimators=num_of_trees, max_depth=5, min_samples_leaf=20)
model=rf_small_entropy.fit(X_df,Y)
res = np.array(model.predict(X_df_test))
diff = res - Z
accuracy = 1/len(res) * sum([1 for x in diff if x == 0])
print(accuracy)
# Out:
# 0.5594364543586733

# %% [markdown]
# # Gini

# %%
# Gini, small tree with train data

criterion = "gini"
dtree_small_gini = DecisionTreeClassifier(criterion=criterion, max_depth=5, min_samples_leaf=20)   # (random_state=1234)
model=dtree_small_gini.fit(X_df,Y)
res = np.array(model.predict(X_df))
diff = res - Y
accuracy = 1/len(res) * sum([1 for x in diff if x == 0])
print(accuracy)
r = export_text(dtree_small_gini, feature_names=list(X_df.columns), class_names=target_names, show_weights=False)
print(r)

# %%
# Gini, large tree with train data
criterion = "gini"
dtree_large_gini = DecisionTreeClassifier(criterion=criterion)   # (random_state=1234)
model=dtree_large_gini.fit(X_df,Y)
res = np.array(model.predict(X_df))
diff = res - Y
accuracy = 1/len(res) * sum([1 for x in diff if x == 0])
print(accuracy)
r = export_text(dtree_large_gini, feature_names=list(X_df.columns), class_names=target_names, show_weights=False)
print(r)

# %%
# Gini, large tree with test data

criterion = "gini"
dtree_large_gini = DecisionTreeClassifier(criterion=criterion)   # (random_state=1234)
model=dtree_large_gini.fit(X_df,Y)
res = np.array(model.predict(X_df_test))
diff = res - Z
accuracy = 1/len(res) * sum([1 for x in diff if x == 0])
print(accuracy)
r = export_text(dtree_large_gini, feature_names=list(X_df.columns), class_names=target_names, show_weights=False)
print(r)

# %%
# Gini, small tree with test data

criterion = "gini"
dtree_small_gini = DecisionTreeClassifier(criterion=criterion, max_depth=5, min_samples_leaf=20)   # (random_state=1234)
model=dtree_small_gini.fit(X_df,Y)
res = np.array(model.predict(X_df_test))
diff = res - Z
accuracy = 1/len(res) * sum([1 for x in diff if x == 0])
print(accuracy)
r = export_text(dtree_small_gini, feature_names=list(X_df.columns), class_names=target_names, show_weights=False)
print(r)

# %% [markdown]
# ## Log_loss

# %%
# Log_loss, small tree with train data

criterion = "log_loss"
dtree_small_Log_loss = DecisionTreeClassifier(criterion=criterion, max_depth=5, min_samples_leaf=20)   # (random_state=1234)
model=dtree_small_Log_loss.fit(X_df,Y)
res = np.array(model.predict(X_df))
diff = res - Y
accuracy = 1/len(res) * sum([1 for x in diff if x == 0])
print(accuracy)
r = export_text(dtree_small_Log_loss, feature_names=list(X_df.columns), class_names=target_names, show_weights=False)
print(r)

# %%
# Log_loss, large tree with train data
criterion = "log_loss"
dtree_large_Log_loss = DecisionTreeClassifier(criterion=criterion)   # (random_state=1234)
model=dtree_large_Log_loss.fit(X_df,Y)
res = np.array(model.predict(X_df))
diff = res - Y
accuracy = 1/len(res) * sum([1 for x in diff if x == 0])
print(accuracy)

# %%
# Log_loss, large tree with test data
criterion = "log_loss"
dtree_large_Log_loss = DecisionTreeClassifier(criterion=criterion)   # (random_state=1234)
model=dtree_large_Log_loss.fit(X_df,Y)
res = np.array(model.predict(X_df_test))
diff = res - Z
accuracy = 1/len(res) * sum([1 for x in diff if x == 0])
print(accuracy)

# %%
p_1 * log p_1 + p_2 * log p_2

# %%
# Log_loss, small tree with test data

criterion = "log_loss"
dtree_small_Log_loss = DecisionTreeClassifier(criterion=criterion, max_depth=5, min_samples_leaf=20)   # (random_state=1234)
model=dtree_small_Log_loss.fit(X_df,Y)
res = np.array(model.predict(X_df_test))
diff = res - Z
accuracy = 1/len(res) * sum([1 for x in diff if x == 0])
print(accuracy)
